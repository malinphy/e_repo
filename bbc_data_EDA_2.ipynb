# %% [markdown]
# <a href="https://colab.research.google.com/github/malinphy/q_17/blob/main/bbc_data_EDA_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def data_loader(data_path):

    f = open(data_path)
    data = json.load(f)

    return data

def column_selection(selected_column, data) :
    empty_column = []
    for i in data:
        empty_column.append(i[selected_column])

    return empty_column

def data_cleaner(txt_data):
    # if limit != None:
    clean_data = []
    empty_indices = []
    for i in range(len(txt_data)):
        if txt_data[i] != '':
                # print(content[i])
            clean_data.append(txt_data[i])
        else :
            empty_indices.append(i)
    # print(empty_indices)
    return clean_data , empty_indices        

def delete_multiple_element(list_object, indices):
    indices = sorted(indices, reverse=True)
    for idx in indices:
        if idx < len(list_object):
            # list_object.pop(idx)
            del list_object[idx] 


def index_returner(df,unique_region):
    x = df[df['region'] == unique_region].index
    return x       

def char_counter(x):
    return  len(x)

def token_counter(x):
    return len(x.split())

# %%
import os 
import json
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# import tensorflow as tf 
# from tensorflow import keras 
# from tensorflow.keras import layers
# from tensorflow.keras.layers import *

plt.style.use('ggplot')

# %%
input_path = 'drive/MyDrive/bbc_news_list_uk.json'
data = data_loader(input_path)
print(data[0].keys())
# Out:
# dict_keys(['tags', 'title', 'news_post_date', 'raw_content', 'content', 'url', 'author', 'language', '_id', 'region', 'short_description', 'category', 'crawled_at'])

# %%
content = column_selection('content', data)
title = column_selection('title', data)
region  = column_selection('region', data)
short_desc = column_selection('short_description', data)
category = column_selection('category', data)

# %%
print('content_len:', len(content))
print('title_len:', len(title))
print('region_len:', len(region))
print('desc_len:', len(short_desc))
print('category_len:', len(category))
# Out:
# content_len: 15825
# title_len: 15825
# region_len: 15825
# desc_len: 15825
# category_len: 15825

# %%
for i in range(len(region)):
    if region[i] == '':
        region[i] = 'NO_INFO'

# %%
clean_content,empty_indices_content = data_cleaner(content)

# %%
clean_title,empty_indices_title = data_cleaner(title)
clean_region,empty_indices_region = data_cleaner(region)
clean_short_desc,empty_indices_short_desc = data_cleaner(short_desc)
clean_category,empty_indices_category = data_cleaner(category)

# %%
# delete_multiple_element(clean_content,empty_indices_content)
delete_multiple_element(clean_title,empty_indices_content)
delete_multiple_element(clean_region,empty_indices_content)
delete_multiple_element(clean_short_desc,empty_indices_content)
delete_multiple_element(clean_category,empty_indices_content)

# %%
print('Clean Content Length :',len(clean_content))
print('Clean Title Length :',len(clean_title))
print('Clean Region Length :',len(clean_region))
print('Clean ShortDescription Length :',len(clean_short_desc))
print('Clean Category Length :',len(clean_category))
# Out:
# Clean Content Length : 15468
# Clean Title Length : 15468
# Clean Region Length : 15468
# Clean ShortDescription Length : 15468
# Clean Category Length : 15468

# %%
df_clean = pd.DataFrame({
    'content': clean_content,
    'title' : clean_title,
    'region' : clean_region,
    'desc' : clean_short_desc,
    'category' : clean_category
})
df_clean.head(1)
# Out:
#                                              content  \
# 0  The heroin substitute methadone can be used as...
#
#                                                title  region  \
# 0  Why quitting heroin substitute methadone is 'v...  Health
#
#                                                 desc  category
# 0  Heroin substitute methadone is used to wean ad...  BBC News

# %%
print('number of unique region :',df_clean['region'].nunique())
# print(df_clean['region'].unique())
# Out:
# number of unique region : 84

# %%
new_df = pd.DataFrame(df_clean.groupby(['region'])['region'].count())
new_df = new_df.rename(columns = {'region':'counts'})
new_df = new_df.reset_index()

# %%
plt.figure(figsize=(25,6))
plt.scatter(new_df['region'], new_df['counts'])
plt.xticks(rotation=90);
plt.yticks(np.arange(0, 1100, 50));
plt.title(['REGION vs # COUNTS']);

# %%
# def json_maker(query, id, content, title, region, desc):
#     return {'query':str(query),'ID':id,'CONTENT':content, 'TITLE':title, 'REGION':region, 'DESCRIPTION':desc}
# def info_print(index_num):
    
#     print('CONTENT:', df_clean['content'][index_num])
#     print('TITLE:', df_clean['title'][index_num])
#     print('REGION:', df_clean['region'][index_num])
#     print('DESC:', df_clean['desc'][index_num])

# %%
df_clean['content_char_length'] = df_clean['content'].apply(char_counter)
df_clean['content_token_length'] = df_clean['content'].apply(token_counter)

print('MEAN VALUE FOR THE CONTENT CHAR LENGTH :',np.mean(df_clean['content_char_length']))
print('MEDIAN VALUE FOR THE CONTENT CHAR LENGTH :',np.median(df_clean['content_char_length']))

print('MEAN VALUE FOR THE CONTENT TOKEN LENGTH :',np.mean(df_clean['content_token_length']))
print('MEDIAN VALUE FOR THE CONTENT TOKEN LENGTH :',np.median(df_clean['content_token_length']))
# Out:
# MEAN VALUE FOR THE CONTENT CHAR LENGTH : 1754.240302560124
# MEDIAN VALUE FOR THE CONTENT CHAR LENGTH : 1404.0
# MEAN VALUE FOR THE CONTENT TOKEN LENGTH : 289.42649340574087
# MEDIAN VALUE FOR THE CONTENT TOKEN LENGTH : 231.0

# %%
df_clean.head(3)
# Out:
#                                              content  \
# 0  The heroin substitute methadone can be used as...
# 1  The eldest son of North Korean leader Kim Jong...
# 2  Seven oil paintings created by notorious gangs...
#
#                                                title        region  \
# 0  Why quitting heroin substitute methadone is 'v...        Health
# 1  North Korea leader's eldest son 'opposes dynasty'  Asia-Pacific
# 2  Paintings by gangster Reggie Kray go on sale i...  Lincolnshire
#
#                                                 desc  category  \
# 0  Heroin substitute methadone is used to wean ad...  BBC News
# 1  The eldest son of North Korean leader Kim Jong...  BBC News
# 2  A series of oil painting produced by gangster ...  BBC News
#
#    content_char_length  content_token_length
# 0                 5234                   907
# 1                 2039                   346
# 2                 1486                   259

# %%
new_df.sort_values(by = ['counts'])
# Out:
#                   region  counts
# 77         US and Canada       1
# 58     Scotland politics       2
# 30                  Home       5
# 57     Scotland business       9
# 42              Magazine      17
# ..                   ...     ...
# 41                London     423
# 74                    UK     537
# 19  Entertainment & Arts     616
# 52      Northern Ireland     877
# 8               Business    1034
#
# [84 rows x 2 columns]

# %% [markdown]
# ## CLUSTERING & DIMENSIONALITY REDUCTION

# %%
# !pip install umap-learn -q
# !pip install hdbscan -q
# !pip install umap-learn[plot] -q

# %%
import umap ### dimensionality reduction algorithm
import hdbscan ### clustering algorithm
import umap.plot
from hdbscan import flat
import plotly.express as px
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()
le.fit_transform(df_clean['region'])
# Out:
# array([27,  1, 39, ..., 27,  7, 74])

# %%
### BBC VECTOR EMBEDDINGS
vector_dir = 'drive/MyDrive/BBC_content_vectors.npy'
embedding_vectors = np.load(vector_dir)
print((embedding_vectors).shape)
# Out:
# (15468, 1536)

# %%
# umap_data = umap.UMAP(n_neighbors=20, n_components=2, min_dist=0, metric='euclidean').fit_transform(embedding_vectors)
umap_data_supervised = umap.UMAP().fit_transform(embedding_vectors, y= le.fit_transform(df_clean['region']))
cluster_supervised = hdbscan.HDBSCAN(
                        min_cluster_size = 30, ## the smallest size grouping that you wish to consider a cluster.
                        metric = 'euclidean' ,
                        # cluster_selection_method = 'eom',
                        min_samples = 18,  ### number of samples in a possible clusters
                        # cluster_selection_epsilon = 200
                        ).fit(umap_data_supervised)

print('NUMBER OF OUTLIER:',len(np.where(np.array(cluster_supervised.labels_) == -1)[0]))              
print('NUMBER OF CLUSTERS:',len(set(cluster_supervised.labels_)))
# Out:
# NUMBER OF OUTLIER: 4237
# NUMBER OF CLUSTERS: 100

# %%
len(set(cluster_supervised.labels_))
# Out:
# 88

# %%
fig, ax = plt.subplots(1, figsize=(25, 10))
plt.scatter(*umap_data_supervised.T,  cmap='Spectral', alpha=1.0)
plt.title('SUPERVISED UMAP');

# %%
cluster_supervised
# Out:
# HDBSCAN(min_cluster_size=20, min_samples=10)

# %%
result = pd.DataFrame(umap_data_supervised, columns=['x', 'y'])
result['labels'] = cluster_supervised.labels_
fig, ax = plt.subplots(figsize=(25, 10))
outliers = result.loc[result.labels == -1, :]
clustered = result.loc[result.labels != -1, :]
plt.scatter(outliers.x, outliers.y,
            color='black',
            s=10)
plt.scatter(clustered.x, clustered.y, c=clustered.labels, s=10,
            cmap='hsv_r'
            )
# plt.xlim([0,20])
# plt.legend([result['labels'].unique()])
# plt.colorbar()
# plt.axis('off')
# plt.xlabel('UMAP1');
# plt.ylabel('UMAP2');
plt.title('SUPERVISED UMAP WITH CLUSTERS');

# %%
# umap_data = umap.UMAP(n_neighbors=20, n_components=2, min_dist=0, metric='euclidean').fit_transform(embedding_vectors)
umap_data_unsupervised = umap.UMAP().fit_transform(embedding_vectors)
cluster_unsupervised = hdbscan.HDBSCAN(
                        min_cluster_size = 20,
                        metric = 'euclidean' ,
                        # cluster_selection_method = 'eom',
                        min_samples = 10
                        ).fit(umap_data_unsupervised)

print('NUMBER OF OUTLIER:',len(np.where(np.array(cluster_unsupervised.labels_) == -1)[0]))
# Out:
# NUMBER OF OUTLIER: 4310

# %%
fig, ax = plt.subplots(1, figsize=(25, 10))
plt.scatter(*umap_data_unsupervised.T,  cmap='Spectral', alpha=1.0)
plt.title('UNSUPERVISED UMAP');

# %%
result = pd.DataFrame(umap_data_unsupervised, columns=['x', 'y'])
result['labels'] = cluster_unsupervised.labels_
fig, ax = plt.subplots(figsize=(25  , 10))
outliers = result.loc[result.labels == -1, :]
clustered = result.loc[result.labels != -1, :]
plt.scatter(outliers.x, outliers.y,
            # color='#BDBDBD',
            s=0.05)
plt.scatter(clustered.x, clustered.y, c=clustered.labels, s=10,
            cmap='hsv_r'
            )
# plt.xlim([0,20])
# plt.legend([result['labels'].unique()])
# plt.colorbar()
# plt.axis('off')
# plt.xlabel('UMAP1');
# plt.ylabel('UMAP2');
plt.title('UNSUPERVISED UMAP WITH CLUSTERS');

# %%
# umap_data_3d = umap.UMAP(n_components=3, init = 'random', random_state = 0).fit_transform(embedding_vectors)
# fig = px.scatter_3d(
#     umap_data_3d, 
#     x=0, y=1, z=2,
#     width=800, height=800,
#     color = cluster.labels_
# )
# fig.show()

# %%
# !pip install transformers -q

# %%
# from transformers import GPT2Tokenizer
# tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# %%
# gpt_tokenizer = []
# for i in range(len(df_clean)):
#     gpt_tokens = tokenizer.encode(df_clean['content'][i])
#     gpt_tokenizer.append(len(gpt_tokens))

# %%
# np.where(np.array(gpt_tokenizer) > 8192)
